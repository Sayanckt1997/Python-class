# %% [markdown]
# # **Pandas**

# %% [markdown]
# Pandas is a powerful open-source Python library used for data manipulation and analysis. It provides easy-to-use data structures, primarily the DataFrame and Series, which allow users to work with structured data efficiently. Pandas is widely used in data science, machine learning, and various data processing tasks because it simplifies operations like cleaning, transforming, and visualizing data.
#
# **What we can do using Pandas**
#
# *   Data visualization
# *   Data import and export
# *   Data manipulation
# *   Data analysis
# *   Data cleaning
# *   Integration with other libraries (NumPy, Matplotlit, Seaborn etc.)

# %%
import pandas as pd

# %% [markdown]
# ## **Creating a Pandas DataFrame**

# %% [markdown]
# 1. From a Python Dictionary

# %%
# Define a dictionary containing employee data
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}

# Convert the dictionary into DataFrame
df_dict = pd.DataFrame(data)

# Print the output
df_dict
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd

# %% [markdown]
# 2. From a List

# %%
data = [['Jai',27,'Delhi','MSc'], ['Princi',24,'Kanpur','MA'], ['Gaurav',22,'Allahabad','MCA'], ['Anuj',32,'Kannauj','Phd']]
df_list = pd.DataFrame(data, columns = ['Name', 'Age', 'Address', 'Qualification'])
df_list
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           MSc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd

# %% [markdown]
# 3. From a CSV file

# %%
diabatis = pd.read_csv('https://raw.githubusercontent.com/Sayanckt1997/Python-class/main/diabetes.csv')
diabatis.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 4. From a JSON File

# %%
import requests
import json

# Fetch the JSON data from the URL
url = 'https://raw.githubusercontent.com/Sayanckt1997/Python-class/main/34.json'
response = requests.get(url)

# Load the JSON data into a dictionary
json_data = response.json()

# Extract the relevant part of the data
# In this case, it might be the "data" field, but you need to check the structure
df_json = pd.DataFrame(json_data['data'])

# Display the DataFrame
df_json
# Out:
#      name spacegroup    volume  ntypes  natoms  band_gap   delta_e
# 0     GaI      F-43m  100.5860       2       2     2.020 -0.335968
# 1    InGa      F-43m   61.8345       2       2     0.000  0.335953
# 2    GaIr      F-43m   43.2972       2       2     0.000  0.537227
# 3     KGa      F-43m  104.7210       2       2     0.000  0.711538
# 4    LaGa      F-43m   79.6179       2       2     0.000  0.347863
# ..    ...        ...       ...     ...     ...       ...       ...
# 495  MoIr      F-43m   44.9987       2       2     0.000  0.988598
# 496   IrN      F-43m   24.8505       2       2     0.000  0.660493
# 497  NaIr      F-43m   66.5767       2       2     0.000  2.380600
# 498  NbIr      F-43m   48.3043       2       2     0.000  0.598632
# 499  NdIr      F-43m   64.7276       2       2     1.298  0.219044
#
# [500 rows x 7 columns]

# %% [markdown]
# 5. From an excel file

# %%
# Create a DataFrame by reading an Excel file
df_excel = pd.read_excel('/content/HH_Dataset.xlsx')
df_excel
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 0            2894          ScSnAu      Au      Sc      Sn  196.9665   44.9559
# 1            3161          LiAlSi      Si      Li      Al   28.0855    6.9410
# 2            3432          ScNiSb      Ni      Sc      Sb   58.7000   44.9559
# 3            3462          TmSnAu      Au      Tm      Sn  196.9665  168.9342
# 4            3522          MgCuSb      Cu      Mg      Sb   63.5460   24.3050
# ..            ...             ...     ...     ...     ...       ...       ...
# 138       1207082          LiMgSb      Sb      Li      Mg  121.7500    6.9410
# 139       1207177          TbBiPd      Pd      Tb      Bi  106.4000  158.9254
# 140       1207185          LuBiPd      Pd      Lu      Bi  106.4000  174.9670
# 141       1216635          TiSnIr      Ir      Ti      Sn  192.2200   47.9000
# 142       1225491          DySbPd      Pd      Dy      Sb  106.4000  162.5000
#
# ...

# %% [markdown]
# Not only these, pandas can play with many other file formats like .xml, .hdf5, .dta, .sql etc.

# %% [markdown]
# 6. From an empty DataFrame

# %%
df = pd.DataFrame()

print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['Chemical Formula'] = df_excel['Chemical Fomula']
df['Lattice Parameter'] = df_excel['L. P.']
df['Thermal Conductivity'] = df_excel['T. C.']
df['Formation Energy'] = df_excel['Formation energy (eV/atom)']
df
# Out:
#     Chemical Formula  Lattice Parameter  Thermal Conductivity  \
# 0             ScSnAu              0.653                  7.09
# 1             LiAlSi              0.594                  5.90
# 2             ScNiSb              0.612                 13.91
# 3             TmSnAu              0.669                  4.61
# 4             MgCuSb              0.625                  3.68
# ..               ...                ...                   ...
# 138           LiMgSb              0.667                 14.63
# 139           TbBiPd              0.675                  6.93
# 140           LuBiPd              0.666                  5.75
# 141           TiSnIr              0.622                  3.90
# 142           DySbPd              0.661                  7.67
#
#      Formation Energy
# 0              -0.794
# 1              -0.222
# 2              -0.911
# 3              -0.868
# 4              -0.283
# ..                ...
# 138            -0.572
# 139            -0.741
# ...

# %%
print(df[['Chemical Formula', 'Lattice Parameter']])
# Out:
#     Chemical Formula  Lattice Parameter
# 0             ScSnAu              0.653
# 1             LiAlSi              0.594
# 2             ScNiSb              0.612
# 3             TmSnAu              0.669
# 4             MgCuSb              0.625
# ..               ...                ...
# 138           LiMgSb              0.667
# 139           TbBiPd              0.675
# 140           LuBiPd              0.666
# 141           TiSnIr              0.622
# 142           DySbPd              0.661
#
# [143 rows x 2 columns]

# %% [markdown]
# ## **Data Visualization**

# %%
df_excel
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 0            2894          ScSnAu      Au      Sc      Sn  196.9665   44.9559
# 1            3161          LiAlSi      Si      Li      Al   28.0855    6.9410
# 2            3432          ScNiSb      Ni      Sc      Sb   58.7000   44.9559
# 3            3462          TmSnAu      Au      Tm      Sn  196.9665  168.9342
# 4            3522          MgCuSb      Cu      Mg      Sb   63.5460   24.3050
# ..            ...             ...     ...     ...     ...       ...       ...
# 138       1207082          LiMgSb      Sb      Li      Mg  121.7500    6.9410
# 139       1207177          TbBiPd      Pd      Tb      Bi  106.4000  158.9254
# 140       1207185          LuBiPd      Pd      Lu      Bi  106.4000  174.9670
# 141       1216635          TiSnIr      Ir      Ti      Sn  192.2200   47.9000
# 142       1225491          DySbPd      Pd      Dy      Sb  106.4000  162.5000
#
# ...

# %%
df_excel.head() #First five rows
# Out:
#    Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 0          2894          ScSnAu      Au      Sc      Sn  196.9665   44.9559
# 1          3161          LiAlSi      Si      Li      Al   28.0855    6.9410
# 2          3432          ScNiSb      Ni      Sc      Sb   58.7000   44.9559
# 3          3462          TmSnAu      Au      Tm      Sn  196.9665  168.9342
# 4          3522          MgCuSb      Cu      Mg      Sb   63.5460   24.3050
#
#    m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  Formation energy (eV/atom)  \
# 0  118.6900   1.503   1.429   1.566  0.653   7.09                      -0.794
# 1   26.9815   1.312   1.085   1.402  0.594   5.90                      -0.222
# 2  121.7500   1.286   1.429   1.577  0.612  13.91                      -0.911
# 3  118.6900   1.503   1.588   1.566  0.669   4.61                      -0.868
# 4  121.7500   1.164   1.524   1.577  0.625   3.68                      -0.283
#
# ...

# %%
df_excel.head(15) #First 15 rows
# Out:
#     Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 0           2894          ScSnAu      Au      Sc      Sn  196.9665   44.9559
# 1           3161          LiAlSi      Si      Li      Al   28.0855    6.9410
# 2           3432          ScNiSb      Ni      Sc      Sb   58.7000   44.9559
# 3           3462          TmSnAu      Au      Tm      Sn  196.9665  168.9342
# 4           3522          MgCuSb      Cu      Mg      Sb   63.5460   24.3050
# 5           3716          TbNiSb      Ni      Tb      Sb   58.7000  158.9254
# 6           4025          TmNiSb      Ni      Tm      Sb   58.7000  168.9342
# 7           4174          HoNiSb      Ni      Ho      Sb   58.7000  164.9304
# 8           4262           BeAlB       B      Be      Al   10.8100    9.0122
# 9           4510          DyNiSb      Ni      Dy      Sb   58.7000  162.5000
# 10          4964           YSbPt      Pt       Y      Sb  195.0900   88.9059
# ...

# %%
df_excel.tail() #Last five rows
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 138       1207082          LiMgSb      Sb      Li      Mg    121.75    6.9410
# 139       1207177          TbBiPd      Pd      Tb      Bi    106.40  158.9254
# 140       1207185          LuBiPd      Pd      Lu      Bi    106.40  174.9670
# 141       1216635          TiSnIr      Ir      Ti      Sn    192.22   47.9000
# 142       1225491          DySbPd      Pd      Dy      Sb    106.40  162.5000
#
#      m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  \
# 138   24.3050   1.577   1.085   1.524  0.667  14.63
# 139  208.9804   1.434   1.588   1.635  0.675   6.93
# 140  208.9804   1.434   1.588   1.635  0.666   5.75
# 141  118.6900   1.423   1.217   1.566  0.622   3.90
# 142  121.7500   1.434   1.588   1.577  0.661   7.67
#
#      Formation energy (eV/atom)  Decomposition energy (eV/atom)  \
# 138                      -0.572                           0.076
# ...

# %%
df_excel.tail(8) #Last 8 rows
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 135       1206989          TbBiPt      Pt      Tb      Bi    195.09  158.9254
# 136       1206992          LuBiPt      Pt      Lu      Bi    195.09  174.9670
# 137       1207057          TmBiPt      Pt      Tm      Bi    195.09  168.9342
# 138       1207082          LiMgSb      Sb      Li      Mg    121.75    6.9410
# 139       1207177          TbBiPd      Pd      Tb      Bi    106.40  158.9254
# 140       1207185          LuBiPd      Pd      Lu      Bi    106.40  174.9670
# 141       1216635          TiSnIr      Ir      Ti      Sn    192.22   47.9000
# 142       1225491          DySbPd      Pd      Dy      Sb    106.40  162.5000
#
#      m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  \
# 135  208.9804   1.455   1.588   1.635  0.677   5.90
# 136  208.9804   1.455   1.588   1.635  0.668   5.77
# 137  208.9804   1.455   1.588   1.635  0.670   5.94
# 138   24.3050   1.577   1.085   1.524  0.667  14.63
# ...

# %%
df_excel.iloc[10:20] #10th to 19th row
# Out:
#     Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 10          4964           YSbPt      Pt       Y      Sb  195.0900   88.9059
# 11          5177          LuSnAu      Au      Lu      Sn  196.9665  174.9670
# 12          5640          ErSnAu      Au      Er      Sn  196.9665  167.2600
# 13          5920          LiAlGe      Ge      Li      Al   72.5900    6.9410
# 14          5967          TiCoSb      Co      Ti      Sb   58.9332   47.9000
# 15          7173          ScSbPt      Pt      Sc      Sb  195.0900   44.9559
# 16          7575           LiZnN       N      Li      Zn   14.0067    6.9410
# 17          9124          LiZnAs      As      Li      Zn   74.9216    6.9410
# 18          9437          NbFeSb      Fe      Nb      Sb   55.8470   92.9064
# 19         10194          LuSbPt      Pt      Lu      Sb  195.0900  174.9670
#
#     m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  \
# 10  121.7500   1.455   1.815   1.577  0.663   3.23
# ...

# %%
df_excel.loc[12:18,['Chemical Fomula', 'L. P.']]
# Out:
#    Chemical Fomula  L. P.
# 12          ErSnAu  0.671
# 13          LiAlGe  0.601
# 14          TiCoSb  0.590
# 15          ScSbPt  0.640
# 16           LiZnN  0.493
# 17          LiZnAs  0.598
# 18          NbFeSb  0.596

# %%
df_excel.info() # summary of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Materials ID                    143 non-null    int64
#  1   Chemical Fomula                 143 non-null    object
#  2   4c site                         143 non-null    object
#  3   4a site                         143 non-null    object
#  4   4b site                         143 non-null    object
#  5   m1 (amu)                        143 non-null    float64
#  6   m2 (amu)                        143 non-null    float64
#  7   m3 (amu)                        143 non-null    float64
#  8   r1 (A)                          143 non-null    float64
#  9   r2 (A)                          143 non-null    float64
#  10  r3 (A)                          143 non-null    float64
#  11  L. P.                           143 non-null    float64
# ...

# %%
df_excel.describe() # descriptive statistics for numeric columns in the DataFrame
# Out:
#        Materials ID    m1 (amu)    m2 (amu)    m3 (amu)      r1 (A)  \
# count  1.430000e+02  143.000000  143.000000  143.000000  143.000000
# mean   5.953607e+05  114.064897   99.648152  124.902529    1.381154
# std    5.067008e+05   61.228155   66.268065   59.922055    0.139814
# min    2.894000e+03    9.012200    6.941000   22.989800    0.741000
# 25%    2.034200e+04   58.700000   44.955900  107.868000    1.286000
# 50%    9.241300e+05  106.400000   91.220000  121.750000    1.434000
# 75%    1.047528e+06  195.090000  164.930400  207.200000    1.455000
# max    1.225491e+06  208.980400  238.029000  208.980400    1.725000
#
#            r2 (A)      r3 (A)       L. P.       T. C.  \
# count  143.000000  143.000000  143.000000  143.000000
# mean     1.443888    1.541070    0.644832    9.250559
# std      0.222709    0.146786    0.047085    6.249145
# min      0.995000    1.164000    0.493000    2.170000
# 25%      1.217000    1.524000    0.619000    4.465000
# ...

# %%
df_excel.shape # number of rows and columns in the DataFrame
# Out:
# (143, 16)

# %%
df_excel.columns # column names in the DataFrame
# Out:
# Index(['Materials ID', 'Chemical Fomula', '4c site', '4a site', '4b site',
#        'm1 (amu)', 'm2 (amu)', 'm3 (amu)', 'r1 (A)', 'r2 (A)', 'r3 (A)',
#        'L. P.', 'T. C.', 'Formation energy (eV/atom)',
#        'Decomposition energy (eV/atom)', 'Stability (ev/atom)'],
#       dtype='object')

# %%
df_excel.dtypes # data types of columns in the DataFrame
# Out:
# Materials ID                        int64
# Chemical Fomula                    object
# 4c site                            object
# 4a site                            object
# 4b site                            object
# m1 (amu)                          float64
# m2 (amu)                          float64
# m3 (amu)                          float64
# r1 (A)                            float64
# r2 (A)                            float64
# r3 (A)                            float64
# L. P.                             float64
# T. C.                             float64
# Formation energy (eV/atom)        float64
# Decomposition energy (eV/atom)    float64
# Stability (ev/atom)               float64
# dtype: object

# %%
df_excel['4c site'].value_counts() # count of unique values in the '4c site' column
# Out:
# 4c site
# Ni    27
# Pt    25
# Pd    22
# Au    15
# Sb     8
# As     6
# Fe     6
# Ru     6
# Co     4
# Si     4
# P      3
# B      2
# Ir     2
# Sn     2
# Tl     1
# Se     1
# Be     1
# Te     1
# Bi     1
# Ga     1
# Os     1
# Cu     1
# N      1
# Ge     1
# Zn     1
# Name: count, dtype: int64

# %%
df_excel['4c site'].unique() # unique values in the '4c site' column
# Out:
# array(['Au', 'Si', 'Ni', 'Cu', 'B', 'Pt', 'Ge', 'Co', 'N', 'As', 'Fe',
#        'P', 'Pd', 'Ru', 'Bi', 'Os', 'Ga', 'Sb', 'Tl', 'Sn', 'Te', 'Ir',
#        'Be', 'Se', 'Zn'], dtype=object)

# %%
df_excel['4c site'].nunique() # Number of unique values in the '4c site' column
# Out:
# 25

# %%
df_excel.duplicated() # check for duplicate rows in the DataFrame
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 138    False
# 139    False
# 140    False
# 141    False
# 142    False
# Length: 143, dtype: bool

# %%
print(df_excel['L. P.'].min())    # Minimum value of 'Lattice parameter' column
print(df_excel['L. P.'].max())    # Maximum value of 'Lattice parameter' column
print(df_excel['L. P.'].mean())   # Mean of 'Lattice parameter' column
print(df_excel['L. P.'].median()) # Median of 'Lattice parameter' column
print(df_excel['L. P.'].std())    # Standard deviation of 'Lattice parameter' column
print(df_excel['L. P.'].var())  # Variance of the 'Lattice parameter' column
print(df_excel['L. P.'].sum())    # Sum of 'Lattice parameter' column
# Out:
# 0.493
# 0.828
# 0.6448321678321678
# 0.647
# 0.04708472824600142
# 0.002216971633999804
# 92.211

# %%
print(df_excel['T. C.'].idxmin())  # Index of the row with the minimum value in the 'Thermal conductivity' column
print(df_excel['T. C.'].idxmax())  # Index of the row with the maximum value in the 'Thermal conductivity' column
# Out:
# 93
# 90

# %%
df_excel.iloc[[90,93]]
# Out:
#     Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 90        961706          TiSiPt      Pt      Ti      Si    195.09     47.90
# 93        961774          BaNaSb      Sb      Ba      Na    121.75    137.33
#
#     m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  \
# 90   28.0855   1.455   1.217   1.312  0.591  34.51
# 93   22.9898   1.577   1.979   1.164  0.796   2.17
#
#     Formation energy (eV/atom)  Decomposition energy (eV/atom)  \
# 90                         NaN                             NaN
# 93                      -0.831                             NaN
#
#     Stability (ev/atom)
# 90                  NaN
# 93                0.067

# %%
df_excel.nsmallest(2, 'T. C.')  # Returns 2 rows with the smallest values in 'Thermal conductivity' column
# Out:
#     Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 93        961774          BaNaSb      Sb      Ba      Na    121.75   137.330
# 35         20269          MnGaPt      Pt      Mn      Ga    195.09    54.938
#
#     m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  \
# 93   22.9898   1.577   1.979   1.164  0.796   2.17
# 35   69.7200   1.455   1.323   1.217  0.600   2.33
#
#     Formation energy (eV/atom)  Decomposition energy (eV/atom)  \
# 93                      -0.831                             NaN
# 35                         NaN                             NaN
#
#     Stability (ev/atom)
# 93                0.067
# 35                  NaN

# %%
df_excel.nlargest(3, 'T. C.')   # Returns 3 rows with the largest values in 'Thermal conductivity' column
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 90         961706          TiSiPt      Pt      Ti      Si   195.090    47.900
# 77         961660          TiFeSe      Fe      Ti      Se    55.847    47.900
# 115       1100409          LiCaSb      Sb      Li      Ca   121.750     6.941
#
#      m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  \
# 90    28.0855   1.455   1.217   1.312  0.591  34.51
# 77    78.9600   1.302   1.217   1.164  0.562  27.60
# 115   40.0800   1.577   1.085   1.323  0.712  26.07
#
#      Formation energy (eV/atom)  Decomposition energy (eV/atom)  \
# 90                          NaN                             NaN
# 77                          NaN                             NaN
# 115                      -0.838                             NaN
#
#      Stability (ev/atom)
# 90                   NaN
# 77                   NaN
# 115                0.119

# %%
# Filtering rows where thermal conductivity is less than than 3
df_excel.query('`T. C.` < 3')
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 35          20269          MnGaPt      Pt      Mn      Ga  195.0900   54.9380
# 75         961657            YNiP      Ni       Y       P   58.7000   88.9059
# 93         961774          BaNaSb      Sb      Ba      Na  121.7500  137.3300
# 112       1100393          LiAgSe      Se      Li      Ag   78.9600    6.9410
# 113       1100403           KBaSb      Sb       K      Ba  121.7500   39.0983
# 123       1100433          CaZnSi      Si      Ca      Zn   28.0855   40.0800
#
#      m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  \
# 35    69.7200   1.455   1.323   1.217  0.600   2.33
# 75    30.9737   1.286   1.815   1.233  0.598   2.37
# 93    22.9898   1.577   1.979   1.164  0.796   2.17
# 112  107.8680   1.164   1.085   1.503  0.628   2.72
# 113  137.3300   1.577   1.588   1.979  0.828   2.88
# 123   65.3800   1.312   1.323   1.270  0.648   2.46
#
# ...

# %%
# Searching using multiple condition
df_excel.query('`T. C.` < 10 and `4a site`== "Li"')
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 1            3161          LiAlSi      Si      Li      Al   28.0855     6.941
# 13           5920          LiAlGe      Ge      Li      Al   72.5900     6.941
# 89         961698           LiZnP       P      Li      Zn   30.9737     6.941
# 96         962069          LiAgTe      Te      Li      Ag  127.6000     6.941
# 112       1100393          LiAgSe      Se      Li      Ag   78.9600     6.941
# 120       1100425          LiCdSb      Sb      Li      Cd  121.7500     6.941
# 122       1100430          LiZnSb      Zn      Li      Sb   65.3800   121.750
# 124       1100436          LiInSi      Si      Li      In   28.0855     6.941
#
#      m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  \
# 1     26.9815   1.312   1.085   1.402  0.594   5.90
# 13    26.9815   1.217   1.085   1.402  0.601   5.08
# 89    65.3800   1.233   1.085   1.270  0.576   9.72
# 96   107.8680   1.535   1.085   1.503  0.664   3.38
# ...

# %%
df_excel.rename(columns={'Chemical Fomula': 'Chemical Formula'})  # Rename of columns
# Out:
#      Materials ID Chemical Formula 4c site 4a site 4b site  m1 (amu)  \
# 0            2894           ScSnAu      Au      Sc      Sn  196.9665
# 1            3161           LiAlSi      Si      Li      Al   28.0855
# 2            3432           ScNiSb      Ni      Sc      Sb   58.7000
# 3            3462           TmSnAu      Au      Tm      Sn  196.9665
# 4            3522           MgCuSb      Cu      Mg      Sb   63.5460
# ..            ...              ...     ...     ...     ...       ...
# 138       1207082           LiMgSb      Sb      Li      Mg  121.7500
# 139       1207177           TbBiPd      Pd      Tb      Bi  106.4000
# 140       1207185           LuBiPd      Pd      Lu      Bi  106.4000
# 141       1216635           TiSnIr      Ir      Ti      Sn  192.2200
# 142       1225491           DySbPd      Pd      Dy      Sb  106.4000
#
#      m2 (amu)  m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  \
# 0     44.9559  118.6900   1.503   1.429   1.566  0.653   7.09
# ...

# %% [markdown]
# ## **Data manipulation**

# %% [markdown]
# ### **Dealing with missing values**

# %%
df_excel.isna() # Check for missing values
# Out:
#      Materials ID  Chemical Fomula  4c site  4a site  4b site  m1 (amu)  \
# 0           False            False    False    False    False     False
# 1           False            False    False    False    False     False
# 2           False            False    False    False    False     False
# 3           False            False    False    False    False     False
# 4           False            False    False    False    False     False
# ..            ...              ...      ...      ...      ...       ...
# 138         False            False    False    False    False     False
# 139         False            False    False    False    False     False
# 140         False            False    False    False    False     False
# 141         False            False    False    False    False     False
# 142         False            False    False    False    False     False
#
#      m2 (amu)  m3 (amu)  r1 (A)  r2 (A)  r3 (A)  L. P.  T. C.  \
# ...

# %%
df_excel.isna().sum() # Count of missing values in each column
# Out:
# Materials ID                        0
# Chemical Fomula                     0
# 4c site                             0
# 4a site                             0
# 4b site                             0
# m1 (amu)                            0
# m2 (amu)                            0
# m3 (amu)                            0
# r1 (A)                              0
# r2 (A)                              0
# r3 (A)                              0
# L. P.                               0
# T. C.                               0
# Formation energy (eV/atom)          9
# Decomposition energy (eV/atom)     59
# Stability (ev/atom)               113
# dtype: int64

# %%
df_modified = df_excel.dropna(subset=['Formation energy (eV/atom)']) # remove rows for missing values of Formation energy
df_modified
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 0            2894          ScSnAu      Au      Sc      Sn  196.9665   44.9559
# 1            3161          LiAlSi      Si      Li      Al   28.0855    6.9410
# 2            3432          ScNiSb      Ni      Sc      Sb   58.7000   44.9559
# 3            3462          TmSnAu      Au      Tm      Sn  196.9665  168.9342
# 4            3522          MgCuSb      Cu      Mg      Sb   63.5460   24.3050
# ..            ...             ...     ...     ...     ...       ...       ...
# 138       1207082          LiMgSb      Sb      Li      Mg  121.7500    6.9410
# 139       1207177          TbBiPd      Pd      Tb      Bi  106.4000  158.9254
# 140       1207185          LuBiPd      Pd      Lu      Bi  106.4000  174.9670
# 141       1216635          TiSnIr      Ir      Ti      Sn  192.2200   47.9000
# 142       1225491          DySbPd      Pd      Dy      Sb  106.4000  162.5000
#
# ...

# %%
df_modified.dropna(axis=1, inplace=True) # remove columns with missing values
df_modified
# Out:
# <ipython-input-37-99face584529>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_modified.dropna(axis=1, inplace=True) # remove columns with missing values
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 0            2894          ScSnAu      Au      Sc      Sn  196.9665   44.9559
# 1            3161          LiAlSi      Si      Li      Al   28.0855    6.9410
# 2            3432          ScNiSb      Ni      Sc      Sb   58.7000   44.9559
# 3            3462          TmSnAu      Au      Tm      Sn  196.9665  168.9342
# 4            3522          MgCuSb      Cu      Mg      Sb   63.5460   24.3050
# ..            ...             ...     ...     ...     ...       ...       ...
# 138       1207082          LiMgSb      Sb      Li      Mg  121.7500    6.9410
# ...

# %%
df_modified.isna().sum() # Count of missing values in each column
# Out:
# Materials ID                  0
# Chemical Fomula               0
# 4c site                       0
# 4a site                       0
# 4b site                       0
# m1 (amu)                      0
# m2 (amu)                      0
# m3 (amu)                      0
# r1 (A)                        0
# r2 (A)                        0
# r3 (A)                        0
# L. P.                         0
# T. C.                         0
# Formation energy (eV/atom)    0
# dtype: int64

# %%
df_modified2 = df_excel.fillna(0) # Replace missing values with 0
df_modified2
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 0            2894          ScSnAu      Au      Sc      Sn  196.9665   44.9559
# 1            3161          LiAlSi      Si      Li      Al   28.0855    6.9410
# 2            3432          ScNiSb      Ni      Sc      Sb   58.7000   44.9559
# 3            3462          TmSnAu      Au      Tm      Sn  196.9665  168.9342
# 4            3522          MgCuSb      Cu      Mg      Sb   63.5460   24.3050
# ..            ...             ...     ...     ...     ...       ...       ...
# 138       1207082          LiMgSb      Sb      Li      Mg  121.7500    6.9410
# 139       1207177          TbBiPd      Pd      Tb      Bi  106.4000  158.9254
# 140       1207185          LuBiPd      Pd      Lu      Bi  106.4000  174.9670
# 141       1216635          TiSnIr      Ir      Ti      Sn  192.2200   47.9000
# 142       1225491          DySbPd      Pd      Dy      Sb  106.4000  162.5000
#
# ...

# %%
df_modified3 = df_excel.copy()
df_modified3['Decomposition energy (eV/atom)'] = df_excel['Decomposition energy (eV/atom)'].fillna(df_excel['Decomposition energy (eV/atom)'].mean()) # Replace missing values with mean
df_modified3
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 0            2894          ScSnAu      Au      Sc      Sn  196.9665   44.9559
# 1            3161          LiAlSi      Si      Li      Al   28.0855    6.9410
# 2            3432          ScNiSb      Ni      Sc      Sb   58.7000   44.9559
# 3            3462          TmSnAu      Au      Tm      Sn  196.9665  168.9342
# 4            3522          MgCuSb      Cu      Mg      Sb   63.5460   24.3050
# ..            ...             ...     ...     ...     ...       ...       ...
# 138       1207082          LiMgSb      Sb      Li      Mg  121.7500    6.9410
# 139       1207177          TbBiPd      Pd      Tb      Bi  106.4000  158.9254
# 140       1207185          LuBiPd      Pd      Lu      Bi  106.4000  174.9670
# 141       1216635          TiSnIr      Ir      Ti      Sn  192.2200   47.9000
# 142       1225491          DySbPd      Pd      Dy      Sb  106.4000  162.5000
#
# ...

# %% [markdown]
# ### **Sorting data**

# %%
df_modified
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 0            2894          ScSnAu      Au      Sc      Sn  196.9665   44.9559
# 1            3161          LiAlSi      Si      Li      Al   28.0855    6.9410
# 2            3432          ScNiSb      Ni      Sc      Sb   58.7000   44.9559
# 3            3462          TmSnAu      Au      Tm      Sn  196.9665  168.9342
# 4            3522          MgCuSb      Cu      Mg      Sb   63.5460   24.3050
# ..            ...             ...     ...     ...     ...       ...       ...
# 138       1207082          LiMgSb      Sb      Li      Mg  121.7500    6.9410
# 139       1207177          TbBiPd      Pd      Tb      Bi  106.4000  158.9254
# 140       1207185          LuBiPd      Pd      Lu      Bi  106.4000  174.9670
# 141       1216635          TiSnIr      Ir      Ti      Sn  192.2200   47.9000
# 142       1225491          DySbPd      Pd      Dy      Sb  106.4000  162.5000
#
# ...

# %%
# Sorting by values in ascending order
df_sorted_by_TC = df_modified.sort_values(by='T. C.')
df_sorted_by_TC
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 93         961774          BaNaSb      Sb      Ba      Na  121.7500  137.3300
# 75         961657            YNiP      Ni       Y       P   58.7000   88.9059
# 123       1100433          CaZnSi      Si      Ca      Zn   28.0855   40.0800
# 113       1100403           KBaSb      Sb       K      Ba  121.7500   39.0983
# 116       1100411          CaCdSn      Sn      Ca      Cd  118.6900   40.0800
# ..            ...             ...     ...     ...     ...       ...       ...
# 80         961673          TiFeTe      Fe      Ti      Te   55.8470   47.9000
# 14           5967          TiCoSb      Co      Ti      Sb   58.9332   47.9000
# 18           9437          NbFeSb      Fe      Nb      Sb   55.8470   92.9064
# 76         961659          TiSiPd      Pd      Ti      Si  106.4000   47.9000
# 115       1100409          LiCaSb      Sb      Li      Ca  121.7500    6.9410
#
# ...

# %%
# Sorting by values in descending order
df_sorted_by_LP = df_modified.sort_values(by='L. P.',ascending=False)
df_sorted_by_LP
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 113       1100403           KBaSb      Sb       K      Ba  121.7500   39.0983
# 121       1100429           KSrSb      Sb       K      Sr  121.7500   39.0983
# 93         961774          BaNaSb      Sb      Ba      Na  121.7500  137.3300
# 118       1100420          NaCaSb      Sb      Na      Ca  121.7500   22.9898
# 94         962063          LaMgTl      Tl      La      Mg  204.3700  138.9055
# ..            ...             ...     ...     ...     ...       ...       ...
# 89         961698           LiZnP       P      Li      Zn   30.9737    6.9410
# 74         961653           FeSiW      Fe      Si       W   55.8470   28.0855
# 111       1100392           LiSiB       B      Li      Si   10.8100    6.9410
# 8            4262           BeAlB       B      Be      Al   10.8100    9.0122
# 16           7575           LiZnN       N      Li      Zn   14.0067    6.9410
#
# ...

# %%
# Sorting by Index
df_sorted_by_index = df_sorted_by_LP.sort_index()
df_sorted_by_index
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 0            2894          ScSnAu      Au      Sc      Sn  196.9665   44.9559
# 1            3161          LiAlSi      Si      Li      Al   28.0855    6.9410
# 2            3432          ScNiSb      Ni      Sc      Sb   58.7000   44.9559
# 3            3462          TmSnAu      Au      Tm      Sn  196.9665  168.9342
# 4            3522          MgCuSb      Cu      Mg      Sb   63.5460   24.3050
# ..            ...             ...     ...     ...     ...       ...       ...
# 138       1207082          LiMgSb      Sb      Li      Mg  121.7500    6.9410
# 139       1207177          TbBiPd      Pd      Tb      Bi  106.4000  158.9254
# 140       1207185          LuBiPd      Pd      Lu      Bi  106.4000  174.9670
# 141       1216635          TiSnIr      Ir      Ti      Sn  192.2200   47.9000
# 142       1225491          DySbPd      Pd      Dy      Sb  106.4000  162.5000
#
# ...

# %%
# Sorting by the first letter of the 'Chemical Formula' column
df_sorted_by_first_letter = df_modified.sort_values(by='Chemical Fomula', key=lambda x: x.str[0])
df_sorted_by_first_letter
# Out:
#      Materials ID Chemical Fomula 4c site 4a site 4b site  m1 (amu)  m2 (amu)  \
# 93         961774          BaNaSb      Sb      Ba      Na  121.7500  137.3300
# 8            4262           BeAlB       B      Be      Al   10.8100    9.0122
# 123       1100433          CaZnSi      Si      Ca      Zn   28.0855   40.0800
# 116       1100411          CaCdSn      Sn      Ca      Cd  118.6900   40.0800
# 95         962068          CaMgSn      Sn      Ca      Mg  118.6900   40.0800
# ..            ...             ...     ...     ...     ...       ...       ...
# 87         961693          ZrInAu      Au      Zr      In  196.9665   91.2200
# 91         961711          ZrSiPt      Pt      Zr      Si  195.0900   91.2200
# 108       1093991          ZrAsIr      Ir      Zr      As  192.2200   91.2200
# 57          31457          ZrSbRu      Ru      Zr      Sb  101.0700   91.2200
# 92         961713          ZrSnPt      Pt      Zr      Sn  195.0900   91.2200
#
# ...

# %% [markdown]
# ### **Mathematics**

# %%
# Sample DataFrame
data = {'A': [2, 4, 6], 'B': [1, 2, 3], 'C': [5, 7, 9]}
df = pd.DataFrame(data)
df
# Out:
#    A  B  C
# 0  2  1  5
# 1  4  2  7
# 2  6  3  9

# %%
df2 = df.copy()
df2['A+B']=df['A']+df['B']
df2['A-C']=df['A']-df['C']
df2['B*C']=df['B']*df['C']
df2['C/A']=df['C']/df['A']
df2
# Out:
#    A  B  C  A+B  A-C  B*C   C/A
# 0  2  1  5    3   -3    5  2.50
# 1  4  2  7    6   -3   14  1.75
# 2  6  3  9    9   -3   27  1.50

# %%
# Column-wise sum
col_sum = df.sum(axis=0)  # axis=0 means column-wise
print(col_sum)

# Row-wise sum
row_sum = df.sum(axis=1)  # axis=1 means row-wise
print(row_sum)
# Out:
# A    12
# B     6
# C    21
# dtype: int64
# 0     8
# 1    13
# 2    18
# dtype: int64

# %%
# Cumulative sum and product
df_cumsum_column = df.cumsum() #by default axis=0
df_cumsum_row = df.cumsum(axis=1)
df_comprod_column = df.cumprod(axis=0)

print('array is:\n',df)
print('cumulative sum through column:\n',df_cumsum_column)
print('cumulative sum through row:\n',df_cumsum_row)
print('cumulative product through column:\n',df_comprod_column)
# Out:
# array is:
#     A  B  C
# 0  2  1  5
# 1  4  2  7
# 2  6  3  9
# cumulative sum through column:
#      A  B   C
# 0   2  1   5
# 1   6  3  12
# 2  12  6  21
# cumulative sum through row:
#     A  B   C
# 0  2  3   8
# 1  4  6  13
# 2  6  9  18
# cumulative product through column:
#      A  B    C
# 0   2  1    5
# 1   8  2   35
# 2  48  6  315

# %%
import numpy as np

df3 = df.copy()
df3['A^2']=df3['A']**2
df3['log(A)']=np.log(df3['A'])
df3['sqrt(A)']=np.sqrt(df3['A'])
df3['exp(A)']=np.exp(df3['A'])
df3['sin(A)']=np.sin(df3['A'])
df3['cos(A)']=np.cos(df3['A'])
df3['tan(A)']=np.tan(df3['A'])
df3['log10(A)']=np.log10(df3['A'])
df3['log2(A)']=np.log2(df3['A'])
df3
# Out:
#    A  B  C  A^2    log(A)   sqrt(A)      exp(A)    sin(A)    cos(A)    tan(A)  \
# 0  2  1  5    4  0.693147  1.414214    7.389056  0.909297 -0.416147 -2.185040
# 1  4  2  7   16  1.386294  2.000000   54.598150 -0.756802 -0.653644  1.157821
# 2  6  3  9   36  1.791759  2.449490  403.428793 -0.279415  0.960170 -0.291006
#
#    log10(A)   log2(A)
# 0  0.301030  1.000000
# 1  0.602060  2.000000
# 2  0.778151  2.584963

# %%
# Pandas provides many built-in statistical functions like
# mean(), median(), std(), var(), min(), max(), etc.
# Mean of each column
df_mean = df.mean()
print(df_mean)

# Standard deviation of C column
df_std = df['C'].std()
print('Standard deviation of "C" column is',df_std)
# Out:
# A    4.0
# B    2.0
# C    7.0
# dtype: float64
# Standard deviation of "C" column is 2.0

# %% [markdown]
# ### **Group By and Aggregate**
# The groupby() function is used to group the DataFrame by one or more columns and then apply an aggregation function to each group.

# %%
# Sample DataFrame with multiple departments
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Department': ['HR', 'IT', 'HR', 'IT', 'HR'],
        'Age': [24, 19, 22, 32, 29],
        'Salary': [50000, 48000, 52000, 58000, 60000]}

df = pd.DataFrame(data)
df
# Out:
#       Name Department  Age  Salary
# 0    Alice         HR   24   50000
# 1      Bob         IT   19   48000
# 2  Charlie         HR   22   52000
# 3    David         IT   32   58000
# 4      Eve         HR   29   60000

# %%
# Group by 'Department' and aggregate using 'mean'
df_grouped = df.groupby('Department')['Salary'].mean()
print(df_grouped)
# Out:
# Department
# HR    54000.0
# IT    53000.0
# Name: Salary, dtype: float64

# %%
# Increase the salary by 10,000 for employees in the 'HR' department
df.loc[df['Department'] == 'HR', 'Salary'] += 10000 #This selects the rows where the 'Department' column is 'HR', and targets the 'Salary' column.
df
# Out:
#       Name Department  Age  Salary
# 0    Alice         HR   24   60000
# 1      Bob         IT   19   48000
# 2  Charlie         HR   22   62000
# 3    David         IT   32   58000
# 4      Eve         HR   29   70000

# %% [markdown]
# ### **Merging and Concating**

# %% [markdown]
# Merging and joining are essential techniques in Pandas for combining datasets.

# %%
#pd.merge(left, right, how='inner', on=None)
#left and right: The two DataFrames to merge.
#how: Type of merge ('left', 'right', 'inner', 'outer').
#on: Column name(s) on which to merge. If not provided, the merge is based on common columns.

# %%
# DataFrame 1
data1 = {'Employee': ['John', 'Alice', 'Bob', 'David'],
         'Department': ['HR', 'IT', 'Finance', 'IT'],
         'Age': [25, 30, 45, 35]}

df1 = pd.DataFrame(data1)

# DataFrame 2
data2 = {'Employee': ['John', 'Alice', 'Bob', 'Michael'],
         'Salary': [50000, 60000, 55000, 65000]}

df2 = pd.DataFrame(data2)

print(df1)
print(df2)
# Out:
#   Employee Department  Age
# 0     John         HR   25
# 1    Alice         IT   30
# 2      Bob    Finance   45
# 3    David         IT   35
#   Employee  Salary
# 0     John   50000
# 1    Alice   60000
# 2      Bob   55000
# 3  Michael   65000

# %%
# Merge DataFrames on 'Employee' column
df_merged = pd.merge(df1, df2, on='Employee', how='inner')
df_merged
# Out:
#   Employee Department  Age  Salary
# 0     John         HR   25   50000
# 1    Alice         IT   30   60000
# 2      Bob    Finance   45   55000

# %%
# Merge DataFrames on 'Employee' column
df_merged = pd.merge(df1, df2, on='Employee', how='outer')
df_merged
# Out:
#   Employee Department   Age   Salary
# 0     John         HR  25.0  50000.0
# 1    Alice         IT  30.0  60000.0
# 2      Bob    Finance  45.0  55000.0
# 3    David         IT  35.0      NaN
# 4  Michael        NaN   NaN  65000.0

# %% [markdown]
# **Concatenating** in Pandas is used to combine two or more DataFrames either vertically (row-wise) or horizontally (column-wise). The **concat()** function in Pandas is used to perform concatenation.

# %%
# DataFrame 1
data1 = {'Name': ['Alice', 'Bob'],
         'Department': ['HR', 'IT'],
         'Salary': [50000, 48000]}

df1 = pd.DataFrame(data1)

# DataFrame 2
data2 = {'Name': ['Charlie', 'David'],
         'Department': ['HR', 'IT'],
         'Salary': [52000, 58000]}

df2 = pd.DataFrame(data2)

print(df1)
print(df2)
# Out:
#     Name Department  Salary
# 0  Alice         HR   50000
# 1    Bob         IT   48000
#       Name Department  Salary
# 0  Charlie         HR   52000
# 1    David         IT   58000

# %%
# Concatenate DataFrames row-wise
df_concat = pd.concat([df1, df2], axis=0, ignore_index=True)

df_concat
# Out:
#       Name Department  Salary
# 0    Alice         HR   50000
# 1      Bob         IT   48000
# 2  Charlie         HR   52000
# 3    David         IT   58000

# %%
# Concatenate DataFrames column-wise
# DataFrame 3
data3 = {'Age': [24, 29, 30, 35]}

df3 = pd.DataFrame(data3)

# Concatenate DataFrames column-wise
df_concat_col = pd.concat([df_concat, df3], axis=1)

df_concat_col
# Out:
#       Name Department  Salary  Age
# 0    Alice         HR   50000   24
# 1      Bob         IT   48000   29
# 2  Charlie         HR   52000   30
# 3    David         IT   58000   35

# %%
# DataFrame with non-matching columns
data4 = {'Name': ['Eve'],
         'Department': ['HR'],
         'Experience': [5]}  # New column 'Experience'

df4 = pd.DataFrame(data4)

# Concatenate with non-matching columns
df_concat_mismatch = pd.concat([df_concat, df4], axis=0, ignore_index=True)

df_concat_mismatch
# Out:
#       Name Department   Salary  Experience
# 0    Alice         HR  50000.0         NaN
# 1      Bob         IT  48000.0         NaN
# 2  Charlie         HR  52000.0         NaN
# 3    David         IT  58000.0         NaN
# 4      Eve         HR      NaN         5.0

# %% [markdown]
# ### **Applying functions**

# %% [markdown]
# The .apply() function in Pandas allows you to apply custom functions to DataFrames or Series, making it a powerful tool for data transformation. You can use it to apply a function to each element, row, or column.

# %%
# Sample DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Age': [24, 19, 22, 32, 29]}

df = pd.DataFrame(data)

df
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   19
# 2  Charlie   22
# 3    David   32
# 4      Eve   29

# %%
# Custom function to increase age by 1
def add_one(x):
    return x + 1

# Applying the function to the 'Age' column
df['Age'] = df['Age'].apply(add_one)

df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   20
# 2  Charlie   23
# 3    David   33
# 4      Eve   30

# %%
#Using .apply() on a DataFrame (Row-wise or Column-wise):
# Function to create a new column with a message based on age
def age_group(row):
    if row['Age'] < 25:
        return 'Young'
    else:
        return 'Adult'

# Apply the function row-wise (axis=1)
df['Age Group'] = df.apply(age_group, axis=1)
df
# Out:
#       Name  Age Age Group
# 0    Alice   25     Adult
# 1      Bob   20     Young
# 2  Charlie   23     Young
# 3    David   33     Adult
# 4      Eve   30     Adult

# %% [markdown]
# Using .apply() with a Lambda Function

# %%
# Use lambda function to square the 'Age' values
df['Age Squared'] = df['Age'].apply(lambda x: x ** 2)

df
# Out:
#       Name  Age Age Group  Age Squared
# 0    Alice   25     Adult          625
# 1      Bob   20     Young          400
# 2  Charlie   23     Young          529
# 3    David   33     Adult         1089
# 4      Eve   30     Adult          900

# %%
# Use lambda function for multi-condition logic
df['Age Category'] = df['Age'].apply(lambda x: 'Young' if x < 30 else ('Middle-Aged' if 30 <= x <= 40 else 'Old'))

df
# Out:
#       Name  Age Age Group  Age Squared Age Category
# 0    Alice   25     Adult          625        Young
# 1      Bob   20     Young          400        Young
# 2  Charlie   23     Young          529        Young
# 3    David   33     Adult         1089  Middle-Aged
# 4      Eve   30     Adult          900  Middle-Aged

# %%
# Apply a string function to convert all names to uppercase
df['Name Upper'] = df['Name'].apply(str.upper)

df
# Out:
#       Name  Age Age Group  Age Squared Age Category Name Upper
# 0    Alice   25     Adult          625        Young      ALICE
# 1      Bob   20     Young          400        Young        BOB
# 2  Charlie   23     Young          529        Young    CHARLIE
# 3    David   33     Adult         1089  Middle-Aged      DAVID
# 4      Eve   30     Adult          900  Middle-Aged        EVE

# %% [markdown]
# ## **Save Data**

# %%
df.to_csv('data.csv', index=True)
df.to_excel('data.xlsx', index=False)
df.to_json('data.json')

# %% [markdown]
# ## **Plotting from a DataFrame**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Sample DataFrame
data = {
    'Year': [2015, 2016, 2017, 2018, 2019, 2020],
    'Sales': [100, 120, 140, 180, 210, 230]
}
df = pd.DataFrame(data)
df
# Out:
#    Year  Sales
# 0  2015    100
# 1  2016    120
# 2  2017    140
# 3  2018    180
# 4  2019    210
# 5  2020    230

# %%
# Line plot
df.plot(x='Year', y='Sales', kind='line', marker='o', title='Yearly Sales')
plt.show()

# %%
# Customizing the plot
ax = df.plot(x='Year', y='Sales', kind='line',
             marker='D', color='purple', linestyle='--',  # Line style and marker
             linewidth=2, markersize=8)  # Custom line width and marker size

# Customizing plot elements with Matplotlib
plt.title('Yearly Sales', fontsize=14)  # Title font size
plt.xlabel('Year', fontsize=16, fontname='serif')  # X-axis label size
plt.ylabel('Sales', fontsize=16, fontname='sans')  # Y-axis label size
plt.grid(True, linestyle=':')  # Custom grid with dotted lines

# Changing xtick and ytick size
plt.xticks(fontsize=10, rotation=45)  # Custom xtick size and rotation
plt.yticks(fontsize=10)  # Custom ytick size

# Display the customized plot
plt.show()

# %%
# Bar plot for sales
df.plot(x='Year', y='Sales', kind='bar', color='orange', title='Yearly Sales Bar Chart')

plt.show()

# %%
# Horizontal bar plot
df.plot(x='Year', y='Sales', kind='barh', color='green', title='Yearly Sales Horizontal Bar')

plt.show()

# %%
# Scatter plot

data = {
    'Year': [2015, 2016, 2017, 2018, 2019, 2020],
    'Sales': [100, 120, 140, 180, 210, 230],
    'Profit': [10, 15, 20, 30, 35, 40]
}
df = pd.DataFrame(data)

# Scatter plot comparing Sales and Profit
df.plot(kind='scatter', x='Sales', y='Profit', marker = '>', s = 100, color='red', title='Sales vs Profit')

plt.show()

# %%
import random
from datetime import datetime, timedelta

# Function to generate sample data
def generate_sample_data(n_rows=100):
    random.seed(42)
    employees = ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank']
    departments = ['HR', 'IT', 'Sales', 'Marketing']
    start_date = datetime(2020, 1, 1)

    data = {
        #'Employee': [random.choice(employees) for _ in range(n_rows)],
        'Department': [random.choice(departments) for _ in range(n_rows)],
        'Sales': np.random.randint(20000, 100000, size=n_rows),
        'Profit': np.random.randint(2000, 20000, size=n_rows),
        'Quantity': np.random.randint(1, 100, size=n_rows),
        'Date': [start_date + timedelta(days=np.random.randint(0, 365)) for _ in range(n_rows)]
    }

    df = pd.DataFrame(data)
    return df

# Create sample DataFrame
df = generate_sample_data()
df
# Out:
#    Department  Sales  Profit  Quantity       Date
# 0          HR  69767   16689        20 2020-08-16
# 1          HR  62872   11275        40 2020-11-20
# 2       Sales  70076   15118        56 2020-02-10
# 3          IT  93296   17275        34 2020-09-20
# 4          IT  60507    6981        21 2020-05-27
# ..        ...    ...     ...       ...        ...
# 95         IT  35795    5112        58 2020-06-03
# 96         IT  49792    8452         1 2020-08-15
# 97  Marketing  68936   15198        23 2020-11-10
# 98         HR  44279    2921        89 2020-10-31
# 99  Marketing  46903    3216        81 2020-04-04
#
# [100 rows x 5 columns]

# %%
# Line Plot using Matplotlib (Sales over Time)
# Sort by Date and plot Sales over Time
df_sorted = df.sort_values('Date')
plt.plot(df_sorted['Date'], df_sorted['Sales'], marker='o')
plt.title('Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Bar plot showing average profit by department
df.groupby('Department')['Profit'].mean().plot(kind='bar', color='green')
plt.title('Average Profit by Department')
plt.xlabel('Department')
plt.ylabel('Average Profit')
plt.grid(axis='y')
plt.show()

# %%
# Scatter plot comparing Sales and Profit
plt.scatter(df['Sales'], df['Profit'], color='blue', alpha=0.5)
plt.title('Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.grid(True)
plt.show()

# %% [markdown]
# A **histogram** is a type of plot that represents the distribution of a dataset. It shows the frequency (or count) of data points that fall within a range of values, known as bins. Each bin represents an interval of values, and the height of the bar in the histogram indicates how many data points fall into that bin.

# %%
# Histogram to visualize the distribution of Sales
df['Sales'].plot(kind='hist', bins=20, color='purple', edgecolor='black')
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Creating a scatter plot with a color bar for the 'Profit' column
scatter = plt.scatter(df['Sales'], df['Quantity'],
                      c=df['Profit'], cmap='viridis', s=100, alpha=0.6)

# Adding a color bar to the plot
plt.colorbar(scatter, label='Profit')

# Customizing the plot
plt.title('Sales vs Quantity with Color Bar for Profit')
plt.xlabel('Sales')
plt.ylabel('Quantity')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
data = {'Sales': np.random.randint(20000, 100000, 100),
        'Profit': np.random.randint(2000, 20000, 100),
        'Quantity': np.random.randint(1, 100, 100),
        'Discount': np.random.uniform(0, 1, 100)}

df = pd.DataFrame(data)
print(df)

# Calculating the correlation matrix
correlation_matrix = df.corr()

# Creating the heatmap using Seaborn
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Adding title
plt.title('Heatmap of Correlation Matrix', fontsize=16)

# Display the plot
plt.show()
# Out:
#     Sales  Profit  Quantity  Discount
# 0   61212    8670        71  0.950818
# 1   40444    4399        25  0.135639
# 2   68820    2514        40  0.523539
# 3   70278    5487        72  0.842931
# 4   79868   19721        39  0.874449
# ..    ...     ...       ...       ...
# 95  93407    6189        69  0.138547
# 96  78178   14265        91  0.252234
# 97  81794    6759        77  0.030543
# 98  56925   14781        35  0.156910
# 99  29503   15040        26  0.763638
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Try plotting with real dataset that are provided
